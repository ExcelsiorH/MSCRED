# %%
#读取train_data_11.npy文件，查看其形状
import pandas as pd
import numpy as np
data=np.load('C:\\Users\\yusei\\Workspace\\异常检测\\MSCRED\\data\\matrix_data\\train_data\\train_data_11.npy')

# %%
data.shape
# Out:
# (5, 3, 11, 11)

# %%
data=np.load('C:\\Users\\yusei\\Workspace\\异常检测\\MSCRED\\data\\matrix_data\\train_data\\0.npy')

# %%
data.shape
# Out:
# (5, 3, 19, 19)
